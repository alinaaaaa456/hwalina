# %% [markdown]
# <a href="https://colab.research.google.com/github/alinaaaaa456/hwalina/blob/main/1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=int(input())
y=x-(x**3 /3)+(x**5 /5)
print(y)
# Out:
# 1
# 0.8666666666666667

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math
x=int(input())
y=int(input())
z=int(input())
w=(3+ math.exp(y-1))/(1+x**2 * abs(y-math.tan(z)))
print(w)
# Out:
# 1
# 2
# 3
# 1.8196331383098583

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math
x=int(input())
y=int(input())
z=(x*x+y*y)/2
w=math.sqrt(abs(x)*abs(y))
print("Среднее арифметическое= ", z)
print("Среднее геометрическое= ", w)
# Out:
# 2
# 2
# Среднее арифметическое=  4.0
# Среднее геометрическое=  2.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Введите двузначное число\n")
x=int(input())
q=x%10
w=x//10
print(q*10+w)
# Out:
# Введите двузначное число
#
# 45
# 54

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x1=int(input())
y1=int(input())
x2=int(input())
y2=int(input())
print("Ладья переходит на новое поле") if(x1==x2 or y1==y2) else print("Ладья не может ходить")
# Out:
# 5
# 1
# 7
# 1
# Ладья переходит на новое поле

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=int(input())
if (x<=7):
  f=-3*x+9
else:
  f=1/(x-7)
print(f)
# Out:
# 7
# -12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=int(input())
y=int(input())
if(x==0):
  print("Точка лежит на оси Х")
elif (y==0):
  print("Точка лежит на оси Y")
else:
  if (x>0):
    print("Точка лежит в I четверти") if (y>0) else print("Точка лежит в IV четверти")
  else:
    print("Точка лежит вo II четверти") if (y>0) else print("Точка лежит в III четверти")
# Out:
# 0
# 0
# Точка лежит на оси Х

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = int(input())
b = int(input())
c = int(input())
if(a>=b>=c):
  a *= a
  b *= b
  c *= c
else:
  a = abs(a)
  b = abs(b)
  c = abs(c)
print(a, b, c)
# Out:
# -5
# -3
# 10
# 5 3 10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math
r = int(input("радиус = "))
a = int(input("сторона квадрата = "))
if(r**2 * math.pi > a**2):
  print("у круга")
elif(r**2 * math.pi == a**2):
  print("они равны")

else:
  print("у квадрата")
# Out:
# радиус = 0
# сторона квадрата = 0
# они равны

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
k = int(input())
k1 = k%7
d = int(input())
if(k1 == d): print("понедельник")
elif(k1 == d+1): print("вторник")
elif(k1 == d+2): print("среда")
elif(k1 == d+3): print("четверг")
elif(k1 == d+4): print("пятница")
elif(k1 == d+5): print("суббота")
else: print("воскресенье")
# Out:
# 3
# 4
# воскресенье

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n=64
g=0
while g*2<=n:
    r=(n-g*2)//4
    if g*2+r*4==n:
        print(f"Гусей: {g}, Кроликов: {r}")
    g=g+1
# Out:
# Гусей: 0, Кроликов: 16
# Гусей: 2, Кроликов: 15
# Гусей: 4, Кроликов: 14
# Гусей: 6, Кроликов: 13
# Гусей: 8, Кроликов: 12
# Гусей: 10, Кроликов: 11
# Гусей: 12, Кроликов: 10
# Гусей: 14, Кроликов: 9
# Гусей: 16, Кроликов: 8
# Гусей: 18, Кроликов: 7
# Гусей: 20, Кроликов: 6
# Гусей: 22, Кроликов: 5
# Гусей: 24, Кроликов: 4
# Гусей: 26, Кроликов: 3
# Гусей: 28, Кроликов: 2
# Гусей: 30, Кроликов: 1
# Гусей: 32, Кроликов: 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def fac(n):
  if n == 1:
    return 1
  return fac(n - 1) * n
x=int(input())
i=1
q=1
y=0
while i<13:
  if q%2==0:
    y=y-x**i/fac(i)
  else:
    y=y+x**i/fac(i)
  i+=1
  q+=1
print(y)
# Out:
# 1
# 0.6321205586787184

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def fac(n):
  if n == 1:
    return 1
  return fac(n - 1) * n

# %% [markdown]
# ![image.png](data:image/png;base64,...)
